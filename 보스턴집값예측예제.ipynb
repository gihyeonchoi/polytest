# %% [markdown]
# <a href="https://colab.research.google.com/github/gihyeonchoi/polytest/blob/main/%EB%B3%B4%EC%8A%A4%ED%84%B4%EC%A7%91%EA%B0%92%EC%98%88%EC%B8%A1%EC%98%88%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf

# %%
file_adress = 'https://raw.githubusercontent.com/gihyeonchoi/polytest/main/boston.csv'
보스턴 = pd.read_csv(file_adress)
print(보스턴.columns)
보스턴.head()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
독립 = 보스턴[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat']]
종속 = 보스턴[['medv']]
print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
X = tf.keras.layers.Input(shape=[13])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
model.fit(독립, 종속, epochs=1000, verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.5299
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.8797
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 26.9154
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 26.5254
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 26.5450
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.5228
# Epoch 7/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.2561
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.6820
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.5372
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.6641

# %%
print(model.predict(독립[5:10]))
print(종속[5:10])
# Out:
# 1/1 [==============================] - 0s 117ms/step
# [[26.330315]
#  [21.136631]
#  [18.009933]
#  [ 9.351588]
#  [17.68613 ]]
#    medv
# 5  28.7
# 6  22.9
# 7  27.1
# 8  16.5
# 9  18.9

# %%
print(model.get_weights())
# Out:
# [array([[-0.08902127],
#        [ 0.07532862],
#        [-0.05675819],
#        [ 3.3370543 ],
#        [ 2.2282572 ],
#        [ 3.7957969 ],
#        [ 0.01916119],
#        [-0.8409599 ],
#        [ 0.14979981],
#        [-0.0099933 ],
#        [ 0.02599235],
#        [ 0.01621419],
#        [-0.5933599 ]], dtype=float32), array([2.9866207], dtype=float32)]
