# %% [markdown]
# <a href="https://colab.research.google.com/github/gihyeonchoi/polytest/blob/main/240322%EB%A0%88%EB%AA%A8%EB%84%A4%EC%9D%B4%EB%93%9C%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf

# %%
file_adress = 'https://raw.githubusercontent.com/gihyeonchoi/polytest/main/lemonade.csv'
lemonade = pd.read_csv(file_adress)

# %%
print(lemonade.shape)
# Out:
# (6, 2)

# %%
독립 = lemonade[["온도"]]
종속 = lemonade[["판매량"]]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
print(lemonade.columns)
# Out:
# Index(['온도', '판매량'], dtype='object')

# %%
lemonade.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
X = tf.keras.layers.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
model.fit(독립, 종속, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 441ms/step - loss: 1467.9030
# Epoch 2/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1462.1989
# Epoch 3/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 1458.0718
# Epoch 4/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1454.6224
# Epoch 5/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1451.5651
# Epoch 6/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1448.7671
# Epoch 7/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1446.1544
# Epoch 8/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1443.6812
# Epoch 9/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1441.3168
# Epoch 10/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1439.0392
# Epoch 11/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1436.8324
# Epoch 12/1000
# ...

# %%
print("Predictions : ", model.predict([[15]]))
# Out:
# 1/1 [==============================] - 0s 37ms/step
# Predictions :  [[20.54191]]
